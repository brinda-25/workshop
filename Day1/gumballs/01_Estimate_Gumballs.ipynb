# %% [markdown]
# # The Gumball Experiment - An Exercise in Estimation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Temporary Workaround to read Google Sheets from MacOs
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ## Download Data

# %%
RAW_ESTIMATES = 'https://docs.google.com/spreadsheets/d/1b8TyWWb2LMYE3_3vAWayTb3tDttOAlCvYg3OQuKBZVI/export?format=csv'

# %%
df = pd.read_csv(RAW_ESTIMATES)
df.head()
# Out:
#             Timestamp        Email Address  How many gumballs do you see ?
# 0  6/17/2026 10:24:49  jiyer2016@gmail.com                             100
# 1  6/17/2026 10:24:56  jiyer2016@gmail.com                             435
# 2  6/17/2026 10:25:02  jiyer2016@gmail.com                              34
# 3  6/17/2026 10:25:09  jiyer2016@gmail.com                              77
# 4  6/17/2026 10:25:15  jiyer2016@gmail.com                             123

# %% [markdown]
# ## Review Data

# %% [markdown]
# ### How many respondents ?

# %%
df.index.size
# Out:
# 67

# %%
df['Email Address'].nunique()
# Out:
# 1

# %% [markdown]
# ### Review Data Distribution

# %% [markdown]
# #### What is the Average / Mean ?

# %%
df['How many gumballs do you see ?'].mean().astype(int).item()
# Out:
# 124

# %% [markdown]
# #### What is the Median ?

# %%
df['How many gumballs do you see ?'].median().astype(int).item()
# Out:
# 87

# %% [markdown]
# #### What is the Mode ?

# %%
df['How many gumballs do you see ?'].mode().item()
# Out:
# 85

# %% [markdown]
# ### Visualize the data distribution

# %%
#df['How many gumballs do you see ?'].plot.kde()

# %%
sns.kdeplot(df['How many gumballs do you see ?'], fill=True)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### Review Other Concepts - Outliers, Bias, IID
